# %% [markdown]
# ###  Pandas Assignment
# #### Question - 1

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN','londON_StockhOlm','Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )','12. Air France', '"Swiss Air"']})

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
# df.set_index("From_To",inplace=True)

# %%
null_rows_series = df['FlightNumber'].isna()

ind =  df['FlightNumber'].loc[null_rows_series].index
# ind

# %%
# print(ind[0])
df.loc[ind[0],'FlightNumber']=10055.0
df.loc[ind[1],'FlightNumber']=10075.0

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %% [markdown]
# #### Question - 2

# %%
'''2. The From_To column would be better as two separate columns! Split each
string on the underscore delimiter _ to give a new temporary DataFrame with
the correct values. Assign the correct column names to this temporary
DataFrame.'''

df_temp=pd.DataFrame()
df_temp[['From','To']] = df.From_To.str.split("_",expand=True,)
df_temp
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %% [markdown]
# #### Question 3

# %%
'''3. Notice how the capitalisation of the city names is all mixed up in this
temporary DataFrame. Standardise the strings so that only the first letter is
uppercase (e.g. "londON" should become "London".)'''

df_temp['From'] = df_temp['From'].str.capitalize()

# %%
df_temp['To'] = df_temp['To'].str.capitalize()

# %%
df_temp
# Out:
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %% [markdown]
# #### Question 4

# %%
'''4. Delete the From_To column from df and attach the temporary DataFrame
from the previous questions.'''

df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
df = df.drop(['From','To'],axis=1)
df
# Out:
#    FlightNumber  RecentDelays              Airline
# 0       10045.0      [23, 47]               KLM(!)
# 1       10055.0            []    <Air France> (12)
# 2       10065.0  [24, 43, 87]  (British Airways. )
# 3       10075.0          [13]       12. Air France
# 4       10085.0      [67, 32]          "Swiss Air"

# %%
df = pd.concat([df,df_temp],axis=1)
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0       10045.0      [23, 47]               KLM(!)    London      Paris
# 1       10055.0            []    <Air France> (12)    Madrid      Milan
# 2       10065.0  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3       10075.0          [13]       12. Air France  Budapest      Paris
# 4       10085.0      [67, 32]          "Swiss Air"  Brussels     London

# %% [markdown]
# #### Question 5

# %%
'''5. In the RecentDelays column, the values have been entered into the
DataFrame as a list. We would like each first value in its own column, each

second value in its own column, and so on. If there isn't an Nth value, the value
should be NaN.
Expand the Series of lists into a DataFrame named delays, rename the columns
delay_1, delay_2, etc. and replace the unwanted RecentDelays column in df
with delays.'''

# %%
for i in df.RecentDelays.values:
#     print(i)
    if(i==[]):
        df['None']='None'
    for j in i:
# #         print(j)
#         if (j==[]):
#             df['None'] ='None'
#         else:
            df[str(j)]=(df.RecentDelays.unique==j)
            df[str(j)] = j

        
df.columns
# Out:
# Index(['FlightNumber', 'RecentDelays', 'Airline', 'From', 'To', '23', '47',
#        'None', '24', '43', '87', '13', '67', '32'],
#       dtype='object')

# %%
# # columns=[23,47,24,43,87,13,67,32,'23','47','24','43','87','13','67','32']
# columns=['23','47','24','43','87','13','67','32']

# %%
# df = df.drop(columns,axis=1)

# %%
# df = df.drop(23,axis=1)

# %%
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To  23  \
# 0       10045.0      [23, 47]               KLM(!)    London      Paris  23
# 1       10055.0            []    <Air France> (12)    Madrid      Milan  23
# 2       10065.0  [24, 43, 87]  (British Airways. )    London  Stockholm  23
# 3       10075.0          [13]       12. Air France  Budapest      Paris  23
# 4       10085.0      [67, 32]          "Swiss Air"  Brussels     London  23
#
#    47  None  24  43  87  13  67  32
# 0  47  None  24  43  87  13  67  32
# 1  47  None  24  43  87  13  67  32
# 2  47  None  24  43  87  13  67  32
# 3  47  None  24  43  87  13  67  32
# 4  47  None  24  43  87  13  67  32

# %%
for i in columns:
    b = ['Delay_' + str(i) for i in columns]
d=dict(zip(columns,b))
# print(b)
df = df.rename(columns=d)
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To  \
# 0       10045.0      [23, 47]               KLM(!)    London      Paris
# 1       10055.0            []    <Air France> (12)    Madrid      Milan
# 2       10065.0  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3       10075.0          [13]       12. Air France  Budapest      Paris
# 4       10085.0      [67, 32]          "Swiss Air"  Brussels     London
#
#    Delay_23  Delay_47  None  Delay_24  Delay_43  Delay_87  Delay_13  Delay_67  \
# 0        23        47  None        24        43        87        13        67
# 1        23        47  None        24        43        87        13        67
# 2        23        47  None        24        43        87        13        67
# 3        23        47  None        24        43        87        13        67
# 4        23        47  None        24        43        87        13        67
#
#    Delay_32
# 0        32
# 1        32
# 2        32
# ...

# %%
Delays = pd.DataFrame()
Delays =  df.iloc[:,5:]
Delays
# Out:
#    Delay_23  Delay_47  None  Delay_24  Delay_43  Delay_87  Delay_13  Delay_67  \
# 0        23        47  None        24        43        87        13        67
# 1        23        47  None        24        43        87        13        67
# 2        23        47  None        24        43        87        13        67
# 3        23        47  None        24        43        87        13        67
# 4        23        47  None        24        43        87        13        67
#
#    Delay_32
# 0        32
# 1        32
# 2        32
# 3        32
# 4        32

# %%
##Lastly what I understood was to change the name of "RecentDelays" TO "Delays"

df = df.rename(columns={'RecentDelays':'Delays'})
df
# Out:
#    FlightNumber        Delays              Airline      From         To  \
# 0       10045.0      [23, 47]               KLM(!)    London      Paris
# 1       10055.0            []    <Air France> (12)    Madrid      Milan
# 2       10065.0  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3       10075.0          [13]       12. Air France  Budapest      Paris
# 4       10085.0      [67, 32]          "Swiss Air"  Brussels     London
#
#    Delay_23  Delay_47  None  Delay_24  Delay_43  Delay_87  Delay_13  Delay_67  \
# 0        23        47  None        24        43        87        13        67
# 1        23        47  None        24        43        87        13        67
# 2        23        47  None        24        43        87        13        67
# 3        23        47  None        24        43        87        13        67
# 4        23        47  None        24        43        87        13        67
#
#    Delay_32
# 0        32
# 1        32
# 2        32
# ...
